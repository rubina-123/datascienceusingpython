# %% [markdown]
# # Python Crash Course Exercises

# %% [markdown]
# ## Exercises
#
# Answer the questions or complete the tasks outlined in bold below, use the specific method described if applicable.

# %% [markdown]
# ** What is 7 to the power of 4?**

# %%
7 ** 4
# Out:
# 2401

# %% [markdown]
# ** Split this string:**
#
#     s = "Hi there Sam!"
#
# **into a list. **

# %%
s = "Hi there Sam!"
s.split()
# Out:
# ['Hi', 'there', 'Sam!']

# %% [markdown]
# ** Given the variables:**
#
#     planet = "Earth"
#     diameter = 12742
#
# ** Use .format() to print the following string: **
#
#     The diameter of Earth is 12742 kilometers.

# %%
planet = "Earth"
diameter = 12742

# %%
planet = "Earth"
diameter = 12742
print("The diameter of {val1} is {val2} kilometers." .format(val1 = planet, val2 = diameter))
# Out:
# The diameter of Earth is 12742 kilometers.

# %% [markdown]
# ** Given this nested list, use indexing to grab the word "hello" **

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
# Out:
# [1, 2, [3, 4], [5, [100, 200, ['hello']], 23, 11], 1, 7]

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
lst[3][1][2][0]
# Out:
# 'hello'

# %% [markdown]
# ** Given this nested dictionary grab the word "hello". Be prepared, this will be annoying/tricky **

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
print(d['k1'(0)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-8b525bfbfda0> in <module>()
#       1 d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
# ----> 2 print(d['k1'(0)])
#
# TypeError: 'str' object is not callable

# %%
print('k')
# Out:
# k

# %% [markdown]
# ** Print the list of all elements using slicing operator ** <br>
# a=[1,2,3,4,5,6,7]

# %%
a = [1,2,3,4,5,6,7]
a[0:6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ** Write a program to print largest of two numbers. Take two numbers from user using input() function**

# %%
a = input("Enter a: ")
b = input("Enter b: ")
a = int(a)
b = int(b)
if a > b:
    print(a) 
else:
    print(b)
# Out:
# Enter a: 23
# Enter b: 2
# 23

# %% [markdown]
# ** Write a program to print largest of three numbers. Take three numbers from user using input() function**

# %%
a = input("Enter a:")
b = input("Enter b:")
c = input("Enter c:")
a = int(a)
b = int(b)
c = int(c)
if a>b & a>c:
    print(a)
elif b > c:
    print(b)
else:
    print(c)
# Out:
# Enter a:5
# Enter b:2
# Enter c:7
# 7

# %% [markdown]
# ** Write a program to check whether the given number palindrome or not**

# %%
num = input("Enter num")
num = int(num)
x = 0
while(num > 0):

    r = num % 10
    x = (x * 10) + 
    num = num / 10
# Out:
# Enter num141
# 1
# 4.1
# 1.41
# 0.141
# 0.014099999999999998
# 0.0014099999999999998
# 0.00014099999999999998
# 1.4099999999999999e-05
# 1.4099999999999998e-06
# 1.4099999999999998e-07
# 1.4099999999999997e-08
# 1.4099999999999997e-09
# 1.4099999999999998e-10
# 1.4099999999999998e-11
# 1.4099999999999998e-12
# 1.4099999999999998e-13
# 1.4099999999999998e-14
# 1.4099999999999998e-15
# 1.4099999999999997e-16
# 1.4099999999999997e-17
# 1.4099999999999998e-18
# 1.4099999999999999e-19
# 1.41e-20
# 1.4099999999999999e-21
# 1.41e-22
# 1.41e-23
# 1.4099999999999999e-24
# 1.41e-25
# 1.41e-26
# 1.41e-27
# 1.41e-28
# 1.41e-29
# 1.41e-30
# 1.41e-31
# 1.41e-32
# 1.4100000000000001e-33
# 1.41e-34
# 1.41e-35
# 1.41e-36
# 1.4099999999999998e-37
# 1.41e-38
# 1.41e-39
# 1.4099999999999999e-40
# 1.41e-41
# 1.4099999999999999e-42
# 1.4099999999999998e-43
# 1.4099999999999998e-44
# 1.4099999999999998e-45
# 1.4099999999999998e-46
# 1.4099999999999997e-47
# 1.4099999999999997e-48
# 1.4099999999999997e-49
# 1.4099999999999997e-50
# 1.4099999999999996e-51
# 1.4099999999999996e-52
# 1.4099999999999995e-53
# 1.4099999999999996e-54
# 1.4099999999999996e-55
# 1.4099999999999996e-56
# 1.4099999999999995e-57
# 1.4099999999999995e-58
# 1.4099999999999995e-59
# 1.4099999999999995e-60
# 1.4099999999999995e-61
# 1.4099999999999995e-62
# 1.4099999999999995e-63
# 1.4099999999999995e-64
# 1.4099999999999994e-65
# 1.4099999999999996e-66
# 1.4099999999999996e-67
# 1.4099999999999996e-68
# 1.4099999999999995e-69
# 1.4099999999999994e-70
# 1.4099999999999995e-71
# 1.4099999999999994e-72
# 1.4099999999999995e-73
# 1.4099999999999995e-74
# 1.4099999999999996e-75
# 1.4099999999999995e-76
# 1.4099999999999994e-77
# 1.4099999999999993e-78
# 1.4099999999999994e-79
# 1.4099999999999994e-80
# 1.4099999999999994e-81
# 1.4099999999999994e-82
# 1.4099999999999994e-83
# 1.4099999999999994e-84
# 1.4099999999999995e-85
# 1.4099999999999995e-86
# 1.4099999999999996e-87
# 1.4099999999999996e-88
# 1.4099999999999996e-89
# 1.4099999999999996e-90
# 1.4099999999999996e-91
# 1.4099999999999996e-92
# 1.4099999999999996e-93
# 1.4099999999999995e-94
# 1.4099999999999996e-95
# 1.4099999999999996e-96
# 1.4099999999999997e-97
# 1.4099999999999997e-98
# 1.4099999999999998e-99
# 1.4099999999999999e-100
# 1.4099999999999999e-101
# 1.4099999999999999e-102
# 1.41e-103
# 1.41e-104
# 1.41e-105
# 1.41e-106
# 1.41e-107
# 1.4100000000000002e-108
# 1.4100000000000002e-109
# 1.41e-110
# 1.4100000000000001e-111
# 1.4100000000000002e-112
# 1.4100000000000002e-113
# 1.4100000000000002e-114
# 1.4100000000000002e-115
# 1.41e-116
# 1.41e-117
# 1.41e-118
# 1.41e-119
# 1.41e-120
# 1.41e-121
# 1.4100000000000002e-122
# 1.4100000000000003e-123
# 1.4100000000000002e-124
# 1.41e-125
# 1.4100000000000001e-126
# 1.4100000000000001e-127
# 1.4100000000000002e-128
# 1.4100000000000001e-129
# 1.4100000000000001e-130
# 1.41e-131
# 1.41e-132
# 1.4099999999999999e-133
# 1.41e-134
# 1.41e-135
# 1.41e-136
# 1.41e-137
# 1.4100000000000002e-138
# 1.4100000000000002e-139
# 1.4100000000000003e-140
# 1.4100000000000003e-141
# 1.4100000000000004e-142
# 1.4100000000000004e-143
# 1.4100000000000004e-144
# 1.4100000000000004e-145
# 1.4100000000000005e-146
# 1.4100000000000004e-147
# 1.4100000000000004e-148
# 1.4100000000000003e-149
# 1.4100000000000003e-150
# 1.4100000000000003e-151
# 1.4100000000000003e-152
# 1.4100000000000002e-153
# 1.4100000000000001e-154
# 1.41e-155
# 1.41e-156
# 1.4099999999999999e-157
# 1.4099999999999998e-158
# 1.41e-159
# 1.41e-160
# 1.41e-161
# 1.41e-162
# 1.41e-163
# 1.41e-164
# 1.41e-165
# 1.41e-166
# 1.41e-167
# 1.41e-168
# 1.41e-169
# 1.41e-170
# 1.41e-171
# 1.41e-172
# 1.4099999999999999e-173
# 1.4099999999999998e-174
# 1.41e-175
# 1.4099999999999998e-176
# 1.4099999999999997e-177
# 1.4099999999999997e-178
# 1.4099999999999997e-179
# 1.4099999999999997e-180
# 1.4099999999999997e-181
# 1.4099999999999997e-182
# 1.4099999999999997e-183
# 1.4099999999999998e-184
# 1.4099999999999998e-185
# 1.4099999999999998e-186
# 1.41e-187
# 1.4099999999999999e-188
# 1.41e-189
# 1.41e-190
# 1.41e-191
# 1.41e-192
# 1.41e-193
# 1.41e-194
# 1.4099999999999999e-195
# 1.41e-196
# 1.41e-197
# 1.4099999999999999e-198
# 1.4099999999999998e-199
# 1.41e-200
# 1.41e-201
# 1.41e-202
# 1.4100000000000002e-203
# 1.4100000000000001e-204
# 1.41e-205
# 1.41e-206
# 1.41e-207
# 1.4100000000000001e-208
# 1.4100000000000002e-209
# 1.4100000000000002e-210
# 1.4100000000000002e-211
# 1.4100000000000003e-212
# 1.4100000000000003e-213
# 1.4100000000000003e-214
# 1.4100000000000003e-215
# 1.4100000000000003e-216
# 1.4100000000000003e-217
# 1.4100000000000003e-218
# 1.4100000000000003e-219
# 1.4100000000000002e-220
# 1.4100000000000002e-221
# 1.4100000000000003e-222
# 1.4100000000000003e-223
# 1.4100000000000003e-224
# 1.4100000000000002e-225
# 1.4100000000000003e-226
# 1.4100000000000004e-227
# 1.4100000000000005e-228
# 1.4100000000000005e-229
# 1.4100000000000006e-230
# 1.4100000000000007e-231
# 1.4100000000000008e-232
# 1.4100000000000007e-233
# 1.4100000000000006e-234
# 1.4100000000000005e-235
# 1.4100000000000006e-236
# 1.4100000000000005e-237
# 1.4100000000000006e-238
# 1.4100000000000006e-239
# 1.4100000000000006e-240
# 1.4100000000000007e-241
# 1.4100000000000007e-242
# 1.4100000000000007e-243
# 1.4100000000000007e-244
# 1.4100000000000008e-245
# 1.4100000000000008e-246
# 1.4100000000000008e-247
# 1.4100000000000007e-248
# 1.4100000000000006e-249
# 1.4100000000000005e-250
# 1.4100000000000005e-251
# 1.4100000000000004e-252
# 1.4100000000000003e-253
# 1.4100000000000004e-254
# 1.4100000000000005e-255
# 1.4100000000000005e-256
# 1.4100000000000005e-257
# 1.4100000000000006e-258
# 1.4100000000000006e-259
# 1.4100000000000006e-260
# 1.4100000000000005e-261
# 1.4100000000000004e-262
# 1.4100000000000005e-263
# 1.4100000000000006e-264
# 1.4100000000000006e-265
# 1.4100000000000006e-266
# 1.4100000000000005e-267
# 1.4100000000000005e-268
# 1.4100000000000004e-269
# 1.4100000000000004e-270
# 1.4100000000000003e-271
# 1.4100000000000003e-272
# 1.4100000000000003e-273
# 1.4100000000000004e-274
# 1.4100000000000005e-275
# 1.4100000000000005e-276
# 1.4100000000000005e-277
# 1.4100000000000005e-278
# 1.4100000000000005e-279
# 1.4100000000000006e-280
# 1.4100000000000007e-281
# 1.4100000000000007e-282
# 1.4100000000000007e-283
# 1.4100000000000008e-284
# 1.4100000000000008e-285
# 1.4100000000000008e-286
# 1.4100000000000008e-287
# 1.4100000000000009e-288
# 1.410000000000001e-289
# 1.410000000000001e-290
# 1.410000000000001e-291
# 1.410000000000001e-292
# 1.410000000000001e-293
# 1.4100000000000008e-294
# 1.4100000000000008e-295
# 1.4100000000000007e-296
# 1.4100000000000007e-297
# 1.4100000000000007e-298
# 1.4100000000000007e-299
# 1.4100000000000007e-300
# 1.4100000000000008e-301
# 1.4100000000000008e-302
# 1.4100000000000008e-303
# 1.410000000000001e-304
# 1.4100000000000008e-305
# 1.4100000000000008e-306
# 1.4100000000000007e-307
# 1.4100000000000006e-308
# 1.41e-309
# 1.41e-310
# 1.41e-311
# 1.41e-312
# 1.41e-313
# 1.41e-314
# 1.41e-315
# 1.41e-316
# 1.41e-317
# 1.41e-318
# 1.41e-319
# 1.41e-320
# 1.41e-321
# 1.4e-322
# 1.5e-323

# %% [markdown]
# ** Write a program to print the Fibonacci series upto n terms **

# %% [markdown]
# # Great job!
